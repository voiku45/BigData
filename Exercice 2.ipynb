# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('./data/sales_predictions.csv')

# %%
df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# 5        10.01.2013               0       25     2564      349.00
# 6        02.01.2013               0       25     2565      549.00
# 7        04.01.2013               0       25     2572      239.00
# 8        11.01.2013               0       25     2572      299.00
# 9        03.01.2013               0       25     2573      299.00
# 10       03.01.2013               0       25     2574      399.00
# 11       05.01.2013               0       25     2574      399.00
# 12       07.01.2013               0       25     2574      399.00
# ...

# %%
sns.relplot(x='date', y='item_price', data=df)

# %%
sns.relplot(x='date', y='item_price', data=df.sample(50))

# %%
sns.relplot(x='date', y='item_price', height=(10), data=df.sample(50))

# %%
pd.to_datetime(df.sample(50).date)
# Out:
# 1099727   2013-08-11
# 2343231   2015-01-30
# 2309173   2014-12-19
# 2720073   2015-07-21
# 2059930   2014-03-10
# 2164441   2014-11-29
# 850294    2013-09-17
# 684215    2013-07-22
# 477629    2013-01-05
# 1638339   2014-07-05
# 1501156   2014-11-03
# 2426429   2015-02-13
# 1295807   2014-07-01
# 1936817   2014-04-08
# 2556292   2015-03-04
# 1186297   2013-12-29
# 2143942   2014-06-11
# 200018    2013-02-13
# 2845865   2015-06-09
# 682151    2013-07-26
# 2519836   2015-03-26
# 473261    2013-05-23
# 2075468   2014-10-17
# 1992232   2014-06-09
# 1831805   2014-07-29
# 2356117   2015-01-01
# 1718685   2014-01-06
# 1828145   2014-07-30
# 2657772   2015-05-22
# 1729831   2014-03-06
# 2657197   2015-05-23
# 1777698   2014-06-22
# 1560738   2014-04-23
# 2893205   2015-10-23
# 1124954   2013-12-18
# 1184817   2013-12-29
# 753803    2013-08-22
# 2591790   2015-12-04
# 413305    2013-09-04
# 2130741   2014-11-29
# 817948    2013-03-08
# 337449    2013-03-28
# 2413963   2015-09-02
# ...

# %%
sns.relplot(x='date', y='item_price', height=(10), data=df.sample(50))
